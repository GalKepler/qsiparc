# %%
from pathlib import Path

from qsiparc.io.loaders import load_recon_inputs

root = Path("/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon")

res = load_recon_inputs(root=root)

# %%
res[0].native_atlases
# Out:
# [AtlasDefinition(name='4S156Parcels', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_seg-4S156Parcels_dseg.nii.gz'), lut=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/atlases/atlas-4S156Parcels/atlas-4S156Parcels_dseg.tsv'), resolution=None, space='ACPC'),
#  AtlasDefinition(name='4S256Parcels', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_seg-4S256Parcels_dseg.nii.gz'), lut=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/atlases/atlas-4S256Parcels/atlas-4S256Parcels_dseg.tsv'), resolution=None, space='ACPC'),
#  AtlasDefinition(name='4S456Parcels', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_seg-4S456Parcels_dseg.nii.gz'), lut=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/atlases/atlas-4S456Parcels/atlas-4S456Parcels_dseg.tsv'), resolution=None, space='ACPC'),
#  AtlasDefinition(name='AAL116', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_seg-AAL116_dseg.nii.gz'), lut=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/atlases/atlas-AAL116/atlas-AAL116_dseg.tsv'), resolution=None, space='ACPC'),
#  AtlasDefinition(name='AICHA384Ext', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_seg-AICHA384Ext_dseg.nii.gz'), lut=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/atlases/atlas-AICHA384Ext/atlas-AICHA384Ext_dseg.tsv'), resolution=None, space='ACPC'),
#  AtlasDefinition(name='Brainnetome246Ext', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_seg-Brainnetome246Ext_dseg.nii.gz'), lut=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/atlases/atlas-Brainnetome246Ext/atlas-Brainnetome246Ext_dseg.tsv'), resolution=None, space='ACPC'),
#  AtlasDefinition(name='Gordon333Ext', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_seg-Gordon333Ext_dseg.nii.gz'), lut=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/atlases/atlas-Gordon333Ext/atlas-Gordon333Ext_dseg.tsv'), resolution=None, space='ACPC')]

# %%
from bids import BIDSLayout

layout = BIDSLayout(
    root,
    validate=False,
    derivatives=True,
    config=["bids", "derivatives"],
)

# %%
filters = {
    "subject": "CLMC10",
    "session": "202407110849",
    # "atlas":"*",
    # "space": "MNI152NLin2009cAsym",
    "suffix": ["dwimap"],
    "extension": ["nii", "nii.gz"],
}
files = layout.get(**filters, return_type="object")
# files

# find what's following the "param-" in the filename

fname = files[1].filename
param_value = fname.split("param-")[1].split("_")[0]
param_value
# files
# Out:
# 'icvf'

# %%
files[1]
# Out:
# <BIDSImageFile filename='/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-noddi_param-icvf_desc-modulated_dwimap.nii.gz'>

# %%
for fobj in files:
    break

# %%
# fobj.get_entities()
entities = fobj.entities.copy()
entities.update({"extension": ["tsv", "csv"]})
# Out:
# {'atlas': '4S156Parcels', 'extension': '.nii.gz', 'res': '01', 'space': 'MNI152NLin2009cAsym', 'suffix': 'dseg'}

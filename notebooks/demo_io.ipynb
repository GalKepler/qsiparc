# %%
from pathlib import Path

from qsiparc.io.loaders import load_recon_inputs

root = Path("/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon")

res = load_recon_inputs(root=root)

# %%
res[0].scalar_maps
# Out:
# [ScalarMapDefinition(name='noddi-direction', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-noddi_param-direction_dwimap.nii.gz'), model='noddi', origin='Peak directions from NODDI', space='ACPC'),
#  ScalarMapDefinition(name='noddi-icvf-modulated', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-noddi_param-icvf_desc-modulated_dwimap.nii.gz'), model='noddi', origin='Peak directions from NODDI', space='ACPC'),
#  ScalarMapDefinition(name='noddi-icvf', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-noddi_param-icvf_dwimap.nii.gz'), model='noddi', origin='Peak directions from NODDI', space='ACPC'),
#  ScalarMapDefinition(name='noddi-isovf', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-noddi_param-isovf_dwimap.nii.gz'), model='noddi', origin='Peak directions from NODDI', space='ACPC'),
#  ScalarMapDefinition(name='noddi-nrmse', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-noddi_param-nrmse_dwimap.nii.gz'), model='noddi', origin='Peak directions from NODDI', space='ACPC'),
#  ScalarMapDefinition(name='noddi-od-modulated', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-noddi_param-od_desc-modulated_dwimap.nii.gz'), model='noddi', origin='Peak directions from NODDI', space='ACPC'),
#  ScalarMapDefinition(name='noddi-od', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-noddi_param-od_dwimap.nii.gz'), model='noddi', origin='Peak directions from NODDI', space='ACPC'),
#  ScalarMapDefinition(name='noddi-rmse', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-noddi_param-rmse_dwimap.nii.gz'), model='noddi', origin='Peak directions from NODDI', space='ACPC'),
#  ScalarMapDefinition(name='noddi-tf', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-noddi_param-tf_dwimap.nii.gz'), model='noddi', origin='Peak directions from NODDI', space='ACPC'),
#  ScalarMapDefinition(name='noddi-icvf-modulated', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-noddi_param-icvf_desc-modulated_dwimap.nii.gz'), model='noddi', origin='Tissue fraction modulated intracellular volume fraction from NODDI', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='noddi-icvf', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-noddi_param-icvf_dwimap.nii.gz'), model='noddi', origin='Intracellular volume fraction from NODDI', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='noddi-isovf', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-noddi_param-isovf_dwimap.nii.gz'), model='noddi', origin='Intracellular volume fraction from NODDI', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='noddi-nrmse', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-noddi_param-nrmse_dwimap.nii.gz'), model='noddi', origin='Intracellular volume fraction from NODDI', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='noddi-od-modulated', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-noddi_param-od_desc-modulated_dwimap.nii.gz'), model='noddi', origin='Tissue fraction modulated intracellular volume fraction from NODDI', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='noddi-od', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-noddi_param-od_dwimap.nii.gz'), model='noddi', origin='Intracellular volume fraction from NODDI', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='noddi-rmse', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-noddi_param-rmse_dwimap.nii.gz'), model='noddi', origin='Intracellular volume fraction from NODDI', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='noddi-tf', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-noddi_param-tf_dwimap.nii.gz'), model='noddi', origin='Intracellular volume fraction from NODDI', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dki-ad', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dki_param-ad_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dki-ak', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dki_param-ak_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dki-kfa', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dki_param-kfa_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dki-linearity', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dki_param-linearity_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dki-md', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dki_param-md_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dki-mk', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dki_param-mk_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dki-mkt', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dki_param-mkt_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dki-planarity', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dki_param-planarity_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dki-rd', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dki_param-rd_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dki-rk', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dki_param-rk_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dki-sphericity', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dki_param-sphericity_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dkimicro-ad', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dkimicro_param-ad_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dkimicro-ade', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dkimicro_param-ade_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dkimicro-awf', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dkimicro_param-awf_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dkimicro-axonald', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dkimicro_param-axonald_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dkimicro-kfa', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dkimicro_param-kfa_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dkimicro-md', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dkimicro_param-md_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dkimicro-rd', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dkimicro_param-rd_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dkimicro-rde', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dkimicro_param-rde_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dkimicro-tortuosity', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dkimicro_param-tortuosity_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='dkimicro-trace', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-dkimicro_param-trace_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='ACPC'),
#  ScalarMapDefinition(name='tensor-fa', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-tensor_param-fa_dwimap.nii.gz'), model='tensor', origin='DKI fractional anisotropy', space='ACPC'),
#  ScalarMapDefinition(name='dki-ad', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dki_param-ad_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dki-ak', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dki_param-ak_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dki-kfa', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dki_param-kfa_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dki-linearity', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dki_param-linearity_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dki-md', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dki_param-md_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dki-mk', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dki_param-mk_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dki-mkt', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dki_param-mkt_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dki-planarity', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dki_param-planarity_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dki-rd', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dki_param-rd_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dki-rk', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dki_param-rk_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dki-sphericity', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dki_param-sphericity_dwimap.nii.gz'), model='dki', origin='DKI axial diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dkimicro-ad', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dkimicro_param-ad_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dkimicro-ade', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dkimicro_param-ade_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dkimicro-awf', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dkimicro_param-awf_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dkimicro-axonald', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dkimicro_param-axonald_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dkimicro-kfa', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dkimicro_param-kfa_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dkimicro-md', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dkimicro_param-md_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dkimicro-rd', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dkimicro_param-rd_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dkimicro-rde', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dkimicro_param-rde_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dkimicro-tortuosity', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dkimicro_param-tortuosity_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='dkimicro-trace', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-dkimicro_param-trace_dwimap.nii.gz'), model='dkimicro', origin='DKI Microstructural Axial Diffusivity', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='tensor-fa', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYDKI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-tensor_param-fa_dwimap.nii.gz'), model='tensor', origin='DKI fractional anisotropy', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='mapmri-lapnorm', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYMAPMRI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-mapmri_param-lapnorm_dwimap.nii.gz'), model='mapmri', origin='Laplacian norm from regularized MAPMRI (MAPL)', space='ACPC'),
#  ScalarMapDefinition(name='mapmri-mapcoeffs', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYMAPMRI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-mapmri_param-mapcoeffs_dwimap.nii.gz'), model='mapmri', origin='Laplacian norm from regularized MAPMRI (MAPL)', space='ACPC'),
#  ScalarMapDefinition(name='mapmri-msd', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYMAPMRI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-mapmri_param-msd_dwimap.nii.gz'), model='mapmri', origin='Laplacian norm from regularized MAPMRI (MAPL)', space='ACPC'),
#  ScalarMapDefinition(name='mapmri-qiv', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYMAPMRI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-mapmri_param-qiv_dwimap.nii.gz'), model='mapmri', origin='Laplacian norm from regularized MAPMRI (MAPL)', space='ACPC'),
#  ScalarMapDefinition(name='mapmri-rtap', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYMAPMRI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-mapmri_param-rtap_dwimap.nii.gz'), model='mapmri', origin='Laplacian norm from regularized MAPMRI (MAPL)', space='ACPC'),
#  ScalarMapDefinition(name='mapmri-rtop', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYMAPMRI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-mapmri_param-rtop_dwimap.nii.gz'), model='mapmri', origin='Laplacian norm from regularized MAPMRI (MAPL)', space='ACPC'),
#  ScalarMapDefinition(name='mapmri-rtpp', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYMAPMRI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-mapmri_param-rtpp_dwimap.nii.gz'), model='mapmri', origin='Laplacian norm from regularized MAPMRI (MAPL)', space='ACPC'),
#  ScalarMapDefinition(name='mapmri-lapnorm', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYMAPMRI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-mapmri_param-lapnorm_dwimap.nii.gz'), model='mapmri', origin='Laplacian norm from regularized MAPMRI (MAPL)', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='mapmri-mapcoeffs', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYMAPMRI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-mapmri_param-mapcoeffs_dwimap.nii.gz'), model='mapmri', origin='Laplacian norm from regularized MAPMRI (MAPL)', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='mapmri-msd', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYMAPMRI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-mapmri_param-msd_dwimap.nii.gz'), model='mapmri', origin='Laplacian norm from regularized MAPMRI (MAPL)', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='mapmri-qiv', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYMAPMRI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-mapmri_param-qiv_dwimap.nii.gz'), model='mapmri', origin='Laplacian norm from regularized MAPMRI (MAPL)', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='mapmri-rtap', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYMAPMRI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-mapmri_param-rtap_dwimap.nii.gz'), model='mapmri', origin='Laplacian norm from regularized MAPMRI (MAPL)', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='mapmri-rtop', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYMAPMRI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-mapmri_param-rtop_dwimap.nii.gz'), model='mapmri', origin='Laplacian norm from regularized MAPMRI (MAPL)', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='mapmri-rtpp', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DIPYMAPMRI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-mapmri_param-rtpp_dwimap.nii.gz'), model='mapmri', origin='Laplacian norm from regularized MAPMRI (MAPL)', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='gqi-gfa', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-gqi_param-gfa_dwimap.nii.gz'), model='gqi', origin='Generalized Fractional Anisotropy', space='ACPC'),
#  ScalarMapDefinition(name='gqi-iso', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-gqi_param-iso_dwimap.nii.gz'), model='gqi', origin='Generalized Fractional Anisotropy', space='ACPC'),
#  ScalarMapDefinition(name='gqi-qa', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-gqi_param-qa_dwimap.nii.gz'), model='gqi', origin='Generalized Fractional Anisotropy', space='ACPC'),
#  ScalarMapDefinition(name='tensor-ad', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-tensor_param-ad_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='ACPC'),
#  ScalarMapDefinition(name='tensor-fa', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-tensor_param-fa_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='ACPC'),
#  ScalarMapDefinition(name='tensor-ha', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-tensor_param-ha_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='ACPC'),
#  ScalarMapDefinition(name='tensor-md', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-tensor_param-md_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='ACPC'),
#  ScalarMapDefinition(name='tensor-rd1', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-tensor_param-rd1_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='ACPC'),
#  ScalarMapDefinition(name='tensor-rd2', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-tensor_param-rd2_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='ACPC'),
#  ScalarMapDefinition(name='tensor-rd', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-tensor_param-rd_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='ACPC'),
#  ScalarMapDefinition(name='tensor-txx', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-tensor_param-txx_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='ACPC'),
#  ScalarMapDefinition(name='tensor-txy', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-tensor_param-txy_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='ACPC'),
#  ScalarMapDefinition(name='tensor-txz', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-tensor_param-txz_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='ACPC'),
#  ScalarMapDefinition(name='tensor-tyy', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-tensor_param-tyy_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='ACPC'),
#  ScalarMapDefinition(name='tensor-tyz', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-tensor_param-tyz_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='ACPC'),
#  ScalarMapDefinition(name='tensor-tzz', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-tensor_param-tzz_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='ACPC'),
#  ScalarMapDefinition(name='gqi-gfa', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-gqi_param-gfa_dwimap.nii.gz'), model='gqi', origin='Generalized Fractional Anisotropy', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='gqi-iso', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-gqi_param-iso_dwimap.nii.gz'), model='gqi', origin='Generalized Fractional Anisotropy', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='gqi-qa', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-gqi_param-qa_dwimap.nii.gz'), model='gqi', origin='Generalized Fractional Anisotropy', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='tensor-ad', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-tensor_param-ad_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='tensor-fa', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-tensor_param-fa_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='tensor-ha', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-tensor_param-ha_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='tensor-md', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-tensor_param-md_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='tensor-rd1', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-tensor_param-rd1_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='tensor-rd2', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-tensor_param-rd2_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='tensor-rd', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-tensor_param-rd_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='tensor-txx', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-tensor_param-txx_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='tensor-txy', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-tensor_param-txy_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='tensor-txz', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-tensor_param-txz_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='tensor-tyy', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-tensor_param-tyy_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='tensor-tyz', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-tensor_param-tyz_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='tensor-tzz', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-DSIStudio/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-MNI152NLin2009cAsym_model-tensor_param-tzz_dwimap.nii.gz'), model='tensor', origin='Axial Diffusivity from a tensor fit. The first eigenvalue of the tensor.', space='MNI152NLin2009cAsym'),
#  ScalarMapDefinition(name='mtnorm-inliermask', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-MRtrix3_act-HSVS/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-mtnorm_param-inliermask_dwimap.nii.gz'), model='mtnorm', origin=None, space='ACPC'),
#  ScalarMapDefinition(name='mtnorm-norm', nifti_path=PosixPath('/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-MRtrix3_act-HSVS/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-mtnorm_param-norm_dwimap.nii.gz'), model='mtnorm', origin=None, space='ACPC')]

# %%
from bids import BIDSLayout

layout = BIDSLayout(
    root,
    validate=False,
    derivatives=True,
    config=["bids", "derivatives"],
)

# %%
filters = {
    "subject": "CLMC10",
    "session": "202407110849",
    # "atlas":"*",
    # "space": "MNI152NLin2009cAsym",
    "suffix": ["dwimap"],
    "extension": ["nii", "nii.gz"],
}
files = layout.get(**filters, return_type="object")
# files

# find what's following the "param-" in the filename

fname = files[1].filename
param_value = fname.split("param-")[1].split("_")[0]
param_value
# files
# Out:
# 'icvf'

# %%
files[1]
# Out:
# <BIDSImageFile filename='/media/storage/yalab-dev/qsiprep_test/derivatives/qsirecon/derivatives/qsirecon-AMICONODDI/sub-CLMC10/ses-202407110849/dwi/sub-CLMC10_ses-202407110849_dir-AP_space-ACPC_model-noddi_param-icvf_desc-modulated_dwimap.nii.gz'>

# %%
for fobj in files:
    break

# %%
# fobj.get_entities()
entities = fobj.entities.copy()
entities.update({"extension": ["tsv", "csv"]})
# Out:
# {'atlas': '4S156Parcels', 'extension': '.nii.gz', 'res': '01', 'space': 'MNI152NLin2009cAsym', 'suffix': 'dseg'}
